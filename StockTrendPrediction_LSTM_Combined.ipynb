# %% [markdown]
# ## Install needed libraries

# %%
import os
from google.colab import drive
drive.mount('/content/gdrive')

path = "/content/gdrive/MyDrive/Chuyên đề nghiên cứu 1/"
# %cd {path}
# !ls
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/Chuyên đề nghiên cứu 1

# %%
# !git clone https://github.com/phamdinhkhanh/vnquant
# %cd vnquant
# !python setup.py install
# Out:
# Cloning into 'vnquant'...
# remote: Enumerating objects: 341, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 341 (delta 65), reused 89 (delta 53), pack-reused 237
# Receiving objects: 100% (341/341), 1.05 MiB | 3.52 MiB/s, done.
# Resolving deltas: 100% (164/164), done.
# /content/gdrive/MyDrive/Chuyên đề nghiên cứu 1/vnquant
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating vnquant.egg-info
# writing vnquant.egg-info/PKG-INFO
# writing dependency_links to vnquant.egg-info/dependency_links.txt
# writing requirements to vnquant.egg-info/requires.txt
# writing top-level names to vnquant.egg-info/top_level.txt
# writing manifest file 'vnquant.egg-info/SOURCES.txt'
# reading manifest file 'vnquant.egg-info/SOURCES.txt'
# writing manifest file 'vnquant.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/vnquant
# copying vnquant/__init__.py -> build/lib/vnquant
# copying vnquant/__version__.py -> build/lib/vnquant
# copying vnquant/utils.py -> build/lib/vnquant
# creating build/lib/vnquant/configs
# copying vnquant/configs/__init__.py -> build/lib/vnquant/configs
# copying vnquant/configs/configs.py -> build/lib/vnquant/configs
# creating build/lib/vnquant/data
# copying vnquant/data/__init__.py -> build/lib/vnquant/data
# copying vnquant/data/dataloader.py -> build/lib/vnquant/data
# copying vnquant/data/finance.py -> build/lib/vnquant/data
# creating build/lib/vnquant/plot
# copying vnquant/plot/Plot.py -> build/lib/vnquant/plot
# copying vnquant/plot/__init__.py -> build/lib/vnquant/plot
# copying vnquant/plot/plot.py -> build/lib/vnquant/plot
# creating build/lib/vnquant/utils
# copying vnquant/utils/__init__.py -> build/lib/vnquant/utils
# copying vnquant/utils/utils.py -> build/lib/vnquant/utils
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/vnquant
# copying build/lib/vnquant/__init__.py -> build/bdist.linux-x86_64/egg/vnquant
# copying build/lib/vnquant/__version__.py -> build/bdist.linux-x86_64/egg/vnquant
# copying build/lib/vnquant/utils.py -> build/bdist.linux-x86_64/egg/vnquant
# creating build/bdist.linux-x86_64/egg/vnquant/configs
# copying build/lib/vnquant/configs/__init__.py -> build/bdist.linux-x86_64/egg/vnquant/configs
# copying build/lib/vnquant/configs/configs.py -> build/bdist.linux-x86_64/egg/vnquant/configs
# creating build/bdist.linux-x86_64/egg/vnquant/data
# copying build/lib/vnquant/data/__init__.py -> build/bdist.linux-x86_64/egg/vnquant/data
# copying build/lib/vnquant/data/dataloader.py -> build/bdist.linux-x86_64/egg/vnquant/data
# copying build/lib/vnquant/data/finance.py -> build/bdist.linux-x86_64/egg/vnquant/data
# creating build/bdist.linux-x86_64/egg/vnquant/plot
# copying build/lib/vnquant/plot/Plot.py -> build/bdist.linux-x86_64/egg/vnquant/plot
# copying build/lib/vnquant/plot/__init__.py -> build/bdist.linux-x86_64/egg/vnquant/plot
# copying build/lib/vnquant/plot/plot.py -> build/bdist.linux-x86_64/egg/vnquant/plot
# creating build/bdist.linux-x86_64/egg/vnquant/utils
# copying build/lib/vnquant/utils/__init__.py -> build/bdist.linux-x86_64/egg/vnquant/utils
# copying build/lib/vnquant/utils/utils.py -> build/bdist.linux-x86_64/egg/vnquant/utils
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/__version__.py to __version__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/configs/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/configs/configs.py to configs.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/data/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/data/dataloader.py to dataloader.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/data/finance.py to finance.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/plot/Plot.py to Plot.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/plot/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/plot/plot.py to plot.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/utils/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/utils/utils.py to utils.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying vnquant.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying vnquant.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying vnquant.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying vnquant.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying vnquant.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying vnquant.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating dist
# creating 'dist/vnquant-0.1.1-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing vnquant-0.1.1-py3.10.egg
# removing '/usr/local/lib/python3.10/dist-packages/vnquant-0.1.1-py3.10.egg' (and everything under it)
# creating /usr/local/lib/python3.10/dist-packages/vnquant-0.1.1-py3.10.egg
# Extracting vnquant-0.1.1-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# vnquant 0.1.1 is already the active version in easy-install.pth
#
# Installed /usr/local/lib/python3.10/dist-packages/vnquant-0.1.1-py3.10.egg
# Processing dependencies for vnquant==0.1.1
# Searching for bs4==0.0.2
# Best match: bs4 0.0.2
# Processing bs4-0.0.2-py3.10.egg
# bs4 0.0.2 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.10/dist-packages/bs4-0.0.2-py3.10.egg
# Searching for plotly==5.15.0
# Best match: plotly 5.15.0
# Adding plotly 5.15.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pypandoc==1.13
# Best match: pypandoc 1.13
# Processing pypandoc-1.13-py3.10.egg
# pypandoc 1.13 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.10/dist-packages/pypandoc-1.13-py3.10.egg
# Searching for lxml==4.9.4
# Best match: lxml 4.9.4
# Adding lxml 4.9.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for wrapt==1.14.1
# Best match: wrapt 1.14.1
# Adding wrapt 1.14.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for requests==2.31.0
# Best match: requests 2.31.0
# Adding requests 2.31.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for numpy==1.25.2
# Best match: numpy 1.25.2
# Adding numpy 1.25.2 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.10 script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pandas==1.5.3
# Best match: pandas 1.5.3
# Adding pandas 1.5.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for beautifulsoup4==4.12.3
# Best match: beautifulsoup4 4.12.3
# Adding beautifulsoup4 4.12.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for packaging==23.2
# Best match: packaging 23.2
# Adding packaging 23.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tenacity==8.2.3
# Best match: tenacity 8.2.3
# Adding tenacity 8.2.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for certifi==2024.2.2
# Best match: certifi 2024.2.2
# Adding certifi 2024.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for urllib3==2.0.7
# Best match: urllib3 2.0.7
# Adding urllib3 2.0.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for idna==3.6
# Best match: idna 3.6
# Adding idna 3.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for charset-normalizer==3.3.2
# Best match: charset-normalizer 3.3.2
# Adding charset-normalizer 3.3.2 to easy-install.pth file
# Installing normalizer script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pytz==2023.4
# Best match: pytz 2023.4
# Adding pytz 2023.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for soupsieve==2.5
# Best match: soupsieve 2.5
# Adding soupsieve 2.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Finished processing dependencies for vnquant==0.1.1

# %%
# %cd ..
# !rm -rf vnquant
# !ls
# Out:
# /content/gdrive/MyDrive/Chuyên đề nghiên cứu 1

# %%
# !pip freeze | grep vnquant
# Out:
# vnquant==0.1.1

# %%
import vnquant
vnquant.__version__
# Out:
# '0.1.1'

# %% [markdown]
# ## Import libraries

# %%
import vnquant.data as dt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# ## We choose 10 codes from biggest companies on stock exchange in Vietnam

# %%
stock_symbols = ['VIC', 'VCB', 'VNM', 'GAS', 'HVN', 'MWG', 'FPT', 'HPG', 'MSN', 'SAB']

# %% [markdown]
# ## Prepare and process the dataset

# %%
stock_data = {}
for i in range(len(stock_symbols)):
  data = dt.DataLoader(symbols=stock_symbols[i],
                        start="2014-01-01",
                        end="2024-01-01",
                        data_source="VND")
  stock_data[stock_symbols[i]] = data.download()

# %%
stock_data[stock_symbols[0]]
# Out:
# Attributes   high    low   open  close    avg     volume
# Symbols       VIC    VIC    VIC    VIC    VIC        VIC
# date
# 2014-01-02  70.50  69.50  70.00  70.00  69.92    74950.0
# 2014-01-03  70.50  69.50  70.00  70.50  70.00    91920.0
# 2014-01-06  70.50  69.50  70.50  70.50  70.11   111760.0
# 2014-01-07  70.50  70.00  70.50  70.50  70.47   294120.0
# 2014-01-08  70.50  70.00  70.00  70.00  70.02   109890.0
# ...           ...    ...    ...    ...    ...        ...
# 2023-12-25  43.55  43.00  43.10  43.40  43.34  3364500.0
# 2023-12-26  43.75  43.35  43.40  43.55  43.55  1806700.0
# 2023-12-27  43.95  43.60  43.65  43.60  43.76  1920500.0
# 2023-12-28  44.60  43.60  43.60  44.45  44.32  4359700.0
# 2023-12-29  44.85  44.45  44.65  44.60  44.63  2474300.0
#
# [2494 rows x 6 columns]

# %%
for i in range(len(stock_symbols)):
  print(f"Length of {stock_symbols[i]} with index {i}: ", len(stock_data[stock_symbols[i]]))
# Out:
# Length of VIC with index 0:  2494
# Length of VCB with index 1:  2494
# Length of VNM with index 2:  2494
# Length of GAS with index 3:  2494
# Length of HVN with index 4:  1743
# Length of MWG with index 5:  2368
# Length of FPT with index 6:  2494
# Length of HPG with index 7:  2494
# Length of MSN with index 8:  2494
# Length of SAB with index 9:  1767

# %%
changed_start_index5 = len(stock_data[stock_symbols[5]]) - len(stock_data[stock_symbols[4]])
stock_data[stock_symbols[5]] = stock_data[stock_symbols[5]][changed_start_index5:]

# %%
changed_start_index9 = len(stock_data[stock_symbols[9]]) - len(stock_data[stock_symbols[4]])
stock_data[stock_symbols[9]] = stock_data[stock_symbols[9]][changed_start_index9:]

# %%
changed_start_other_index = len(stock_data[stock_symbols[0]]) - len(stock_data[stock_symbols[4]])
for i in range(len(stock_symbols)):
  if ((i == 4) or (i == 5) or (i == 9)):
    pass
  else:
    stock_data[stock_symbols[i]] = stock_data[stock_symbols[i]][changed_start_other_index:]

# %%
combined_high = (stock_data[stock_symbols[0]]['high'].values + stock_data[stock_symbols[1]]['high'].values + stock_data[stock_symbols[2]]['high'].values +
                 stock_data[stock_symbols[3]]['high'].values + stock_data[stock_symbols[4]]['high'].values + stock_data[stock_symbols[5]]['high'].values +
                 stock_data[stock_symbols[6]]['high'].values + stock_data[stock_symbols[7]]['high'].values + stock_data[stock_symbols[8]]['high'].values +
                 stock_data[stock_symbols[9]]['high'].values) / len(stock_symbols)
combined_high
# Out:
# array([[82.885],
#        [83.95 ],
#        [85.11 ],
#        ...,
#        [58.545],
#        [58.44 ],
#        [58.635]])

# %%
combined_low = (stock_data[stock_symbols[0]]['low'].values + stock_data[stock_symbols[1]]['low'].values + stock_data[stock_symbols[2]]['low'].values +
                 stock_data[stock_symbols[3]]['low'].values + stock_data[stock_symbols[4]]['low'].values + stock_data[stock_symbols[5]]['low'].values +
                 stock_data[stock_symbols[6]]['low'].values + stock_data[stock_symbols[7]]['low'].values + stock_data[stock_symbols[8]]['low'].values +
                 stock_data[stock_symbols[9]]['low'].values) / len(stock_symbols)
combined_low
# Out:
# array([[81.455],
#        [82.445],
#        [83.565],
#        ...,
#        [57.755],
#        [57.685],
#        [57.625]])

# %%
combined_open = (stock_data[stock_symbols[0]]['open'].values + stock_data[stock_symbols[1]]['open'].values + stock_data[stock_symbols[2]]['open'].values +
                 stock_data[stock_symbols[3]]['open'].values + stock_data[stock_symbols[4]]['open'].values + stock_data[stock_symbols[5]]['open'].values +
                 stock_data[stock_symbols[6]]['open'].values + stock_data[stock_symbols[7]]['open'].values + stock_data[stock_symbols[8]]['open'].values +
                 stock_data[stock_symbols[9]]['open'].values) / len(stock_symbols)
combined_open
# Out:
# array([[82.255],
#        [82.795],
#        [84.76 ],
#        ...,
#        [58.055],
#        [58.01 ],
#        [58.325]])

# %%
combined_close = (stock_data[stock_symbols[0]]['close'].values + stock_data[stock_symbols[1]]['close'].values + stock_data[stock_symbols[2]]['close'].values +
                 stock_data[stock_symbols[3]]['close'].values + stock_data[stock_symbols[4]]['close'].values + stock_data[stock_symbols[5]]['close'].values +
                 stock_data[stock_symbols[6]]['close'].values + stock_data[stock_symbols[7]]['close'].values + stock_data[stock_symbols[8]]['close'].values +
                 stock_data[stock_symbols[9]]['close'].values) / len(stock_symbols)
combined_close
# Out:
# array([[82.185],
#        [83.725],
#        [84.06 ],
#        ...,
#        [57.93 ],
#        [58.09 ],
#        [57.71 ]])

# %%
combined_avg = (stock_data[stock_symbols[0]]['avg'].values + stock_data[stock_symbols[1]]['avg'].values + stock_data[stock_symbols[2]]['avg'].values +
                 stock_data[stock_symbols[3]]['avg'].values + stock_data[stock_symbols[4]]['avg'].values + stock_data[stock_symbols[5]]['avg'].values +
                 stock_data[stock_symbols[6]]['avg'].values + stock_data[stock_symbols[7]]['avg'].values + stock_data[stock_symbols[8]]['avg'].values +
                 stock_data[stock_symbols[9]]['avg'].values) / len(stock_symbols)
combined_avg
# Out:
# array([[82.107 ],
#        [83.28  ],
#        [84.3326],
#        ...,
#        [58.148 ],
#        [58.099 ],
#        [58.183 ]])

# %%
combined_volume = (stock_data[stock_symbols[0]]['volume'].values + stock_data[stock_symbols[1]]['volume'].values + stock_data[stock_symbols[2]]['volume'].values +
                 stock_data[stock_symbols[3]]['volume'].values + stock_data[stock_symbols[4]]['volume'].values + stock_data[stock_symbols[5]]['volume'].values +
                 stock_data[stock_symbols[6]]['volume'].values + stock_data[stock_symbols[7]]['volume'].values + stock_data[stock_symbols[8]]['volume'].values +
                 stock_data[stock_symbols[9]]['volume'].values) / len(stock_symbols)
combined_volume
# Out:
# array([[ 747272. ],
#        [ 605305.8],
#        [ 643985. ],
#        ...,
#        [4714230. ],
#        [5987070. ],
#        [5748880.1]])

# %%
df = pd.DataFrame(combined_high)
df.head()
# Out:
#         0
# 0  82.885
# 1  83.950
# 2  85.110
# 3  84.750
# 4  83.620

# %%
df = df.rename(columns={0: 'high'})

df['low'] = combined_low
df['open'] = combined_open
df['close'] = combined_close
df['avg'] = combined_avg
df['volume'] = combined_volume

df.head()
# Out:
#      high     low    open   close      avg    volume
# 0  82.885  81.455  82.255  82.185  82.1070  747272.0
# 1  83.950  82.445  82.795  83.725  83.2800  605305.8
# 2  85.110  83.565  84.760  84.060  84.3326  643985.0
# 3  84.750  83.060  84.335  83.335  83.6911  727448.6
# 4  83.620  82.000  83.465  82.270  82.5046  722580.3

# %%
df = df.ewm(alpha=0.65).mean()
df.head()
# Out:
#         high        low       open      close        avg         volume
# 0  82.885000  81.455000  82.255000  82.185000  82.107000  747272.000000
# 1  83.673889  82.188333  82.655000  83.325741  82.975889  642111.851852
# 2  84.649177  83.123251  84.084542  83.824389  83.897255  643383.938879
# 3  84.715710  83.081512  84.249820  83.501440  83.761213  698858.432731
# 4  83.999738  82.374817  83.736993  82.696778  82.940102  714359.058650

# %%
df['percentage_change'] = df['close'].pct_change() * 100
df.head()
# Out:
#         high        low       open      close        avg         volume  \
# 0  82.885000  81.455000  82.255000  82.185000  82.107000  747272.000000
# 1  83.673889  82.188333  82.655000  83.325741  82.975889  642111.851852
# 2  84.649177  83.123251  84.084542  83.824389  83.897255  643383.938879
# 3  84.715710  83.081512  84.249820  83.501440  83.761213  698858.432731
# 4  83.999738  82.374817  83.736993  82.696778  82.940102  714359.058650
#
#    percentage_change
# 0                NaN
# 1           1.388016
# 2           0.598432
# 3          -0.385269
# 4          -0.963651

# %%
for i in range(1, 6):
  df[f'previous{str(i)}'] = df['percentage_change'].shift(i)

df.head()
# Out:
#         high        low       open      close        avg         volume  \
# 0  82.885000  81.455000  82.255000  82.185000  82.107000  747272.000000
# 1  83.673889  82.188333  82.655000  83.325741  82.975889  642111.851852
# 2  84.649177  83.123251  84.084542  83.824389  83.897255  643383.938879
# 3  84.715710  83.081512  84.249820  83.501440  83.761213  698858.432731
# 4  83.999738  82.374817  83.736993  82.696778  82.940102  714359.058650
#
#    percentage_change  previous1  previous2  previous3  previous4  previous5
# 0                NaN        NaN        NaN        NaN        NaN        NaN
# 1           1.388016        NaN        NaN        NaN        NaN        NaN
# 2           0.598432   1.388016        NaN        NaN        NaN        NaN
# 3          -0.385269   0.598432   1.388016        NaN        NaN        NaN
# 4          -0.963651  -0.385269   0.598432   1.388016        NaN        NaN

# %%
df['ema50'] = df['close'] / df['close'].ewm(50).mean()
df['ema21'] = df['close'] / df['close'].ewm(21).mean()
df['ema14'] = df['close'] / df['close'].ewm(14).mean()
df['ema5'] = df['close'] / df['close'].ewm(5).mean()

df.head()
# Out:
#         high        low       open      close        avg         volume  \
# 0  82.885000  81.455000  82.255000  82.185000  82.107000  747272.000000
# 1  83.673889  82.188333  82.655000  83.325741  82.975889  642111.851852
# 2  84.649177  83.123251  84.084542  83.824389  83.897255  643383.938879
# 3  84.715710  83.081512  84.249820  83.501440  83.761213  698858.432731
# 4  83.999738  82.374817  83.736993  82.696778  82.940102  714359.058650
#
#    percentage_change  previous1  previous2  previous3  previous4  previous5  \
# 0                NaN        NaN        NaN        NaN        NaN        NaN
# 1           1.388016        NaN        NaN        NaN        NaN        NaN
# 2           0.598432   1.388016        NaN        NaN        NaN        NaN
# 3          -0.385269   0.598432   1.388016        NaN        NaN        NaN
# 4          -0.963651  -0.385269   0.598432   1.388016        NaN        NaN
#
#       ema50     ema21     ema14      ema5
# 0  1.000000  1.000000  1.000000  1.000000
# 1  1.006824  1.006731  1.006653  1.006262
# 2  1.008444  1.008268  1.008120  1.007388
# 3  1.003381  1.003206  1.003061  1.002375
# 4  0.995013  0.994947  0.994897  0.994735

# %%
def rsi(X, window=14):
  delta = X.diff(1)

  gains = delta.where(delta > 0, 0)
  losses = -delta.where(delta < 0, 0)

  avg_gains = gains.rolling(window=window, min_periods=1).mean()
  avg_losses = losses.rolling(window=window, min_periods=1).mean()

  rs = avg_gains / avg_losses
  rsi = 100 - (100 / (1 + rs))

  return rsi

# %%
df['rsi'] = rsi(df['close'])
df.head()
# Out:
#         high        low       open      close        avg         volume  \
# 0  82.885000  81.455000  82.255000  82.185000  82.107000  747272.000000
# 1  83.673889  82.188333  82.655000  83.325741  82.975889  642111.851852
# 2  84.649177  83.123251  84.084542  83.824389  83.897255  643383.938879
# 3  84.715710  83.081512  84.249820  83.501440  83.761213  698858.432731
# 4  83.999738  82.374817  83.736993  82.696778  82.940102  714359.058650
#
#    percentage_change  previous1  previous2  previous3  previous4  previous5  \
# 0                NaN        NaN        NaN        NaN        NaN        NaN
# 1           1.388016        NaN        NaN        NaN        NaN        NaN
# 2           0.598432   1.388016        NaN        NaN        NaN        NaN
# 3          -0.385269   0.598432   1.388016        NaN        NaN        NaN
# 4          -0.963651  -0.385269   0.598432   1.388016        NaN        NaN
#
#       ema50     ema21     ema14      ema5         rsi
# 0  1.000000  1.000000  1.000000  1.000000         NaN
# 1  1.006824  1.006731  1.006653  1.006262  100.000000
# 2  1.008444  1.008268  1.008120  1.007388  100.000000
# 3  1.003381  1.003206  1.003061  1.002375   83.542641
# 4  0.995013  0.994947  0.994897  0.994735   59.247881

# %%
def macd(X, short_window=12, long_window=29, signal=9):
  short_ema = X.ewm(span=short_window, adjust=False).mean()

  long_ema = X.ewm(span=long_window, adjust=False).mean()

  macd = short_ema - long_ema

  signal = macd.ewm(span=signal, adjust=False).mean()

  return signal

# %%
df['macd'] = macd(df['close'])
df.head()
# Out:
#         high        low       open      close        avg         volume  \
# 0  82.885000  81.455000  82.255000  82.185000  82.107000  747272.000000
# 1  83.673889  82.188333  82.655000  83.325741  82.975889  642111.851852
# 2  84.649177  83.123251  84.084542  83.824389  83.897255  643383.938879
# 3  84.715710  83.081512  84.249820  83.501440  83.761213  698858.432731
# 4  83.999738  82.374817  83.736993  82.696778  82.940102  714359.058650
#
#    percentage_change  previous1  previous2  previous3  previous4  previous5  \
# 0                NaN        NaN        NaN        NaN        NaN        NaN
# 1           1.388016        NaN        NaN        NaN        NaN        NaN
# 2           0.598432   1.388016        NaN        NaN        NaN        NaN
# 3          -0.385269   0.598432   1.388016        NaN        NaN        NaN
# 4          -0.963651  -0.385269   0.598432   1.388016        NaN        NaN
#
#       ema50     ema21     ema14      ema5         rsi      macd
# 0  1.000000  1.000000  1.000000  1.000000         NaN  0.000000
# 1  1.006824  1.006731  1.006653  1.006262  100.000000  0.019890
# 2  1.008444  1.008268  1.008120  1.007388  100.000000  0.060000
# 3  1.003381  1.003206  1.003061  1.002375   83.542641  0.105115
# 4  0.995013  0.994947  0.994897  0.994735   59.247881  0.136880

# %%
window = 6
df['roc'] = ((df['close'] - df['close'].shift(window)) / df['close'].shift(window)) * 100

df.head()
# Out:
#         high        low       open      close        avg         volume  \
# 0  82.885000  81.455000  82.255000  82.185000  82.107000  747272.000000
# 1  83.673889  82.188333  82.655000  83.325741  82.975889  642111.851852
# 2  84.649177  83.123251  84.084542  83.824389  83.897255  643383.938879
# 3  84.715710  83.081512  84.249820  83.501440  83.761213  698858.432731
# 4  83.999738  82.374817  83.736993  82.696778  82.940102  714359.058650
#
#    percentage_change  previous1  previous2  previous3  previous4  previous5  \
# 0                NaN        NaN        NaN        NaN        NaN        NaN
# 1           1.388016        NaN        NaN        NaN        NaN        NaN
# 2           0.598432   1.388016        NaN        NaN        NaN        NaN
# 3          -0.385269   0.598432   1.388016        NaN        NaN        NaN
# 4          -0.963651  -0.385269   0.598432   1.388016        NaN        NaN
#
#       ema50     ema21     ema14      ema5         rsi      macd  roc
# 0  1.000000  1.000000  1.000000  1.000000         NaN  0.000000  NaN
# 1  1.006824  1.006731  1.006653  1.006262  100.000000  0.019890  NaN
# 2  1.008444  1.008268  1.008120  1.007388  100.000000  0.060000  NaN
# 3  1.003381  1.003206  1.003061  1.002375   83.542641  0.105115  NaN
# 4  0.995013  0.994947  0.994897  0.994735   59.247881  0.136880  NaN

# %%
window = 16

df['high-low'] = df['high'] - df['low']
df['high-preclose'] = abs(df['high'] - df['close'].shift(1))
df['low-preclose'] = abs(df['low'] - df['close'].shift(1))
df['tr'] = df[[('high-low'), ('high-preclose'), ('low-preclose')]].max(axis=1)
df['atr'] = df['tr'].rolling(window=window).mean()

# %%
df = df.drop(['high-low', 'high-preclose', 'low-preclose', 'tr'], axis=1)

# %%
def obv(X):
  obv = pd.Series(index=X.index)
  obv.iloc[0] = 0

  for i in range(1, len(X)):
    if (X['close'].iloc[i] > X['close'].iloc[i-1]):
      obv.iloc[i] = obv.iloc[i-1] + X['volume'].iloc[i]
    elif (X['close'].iloc[i] < X['close'].iloc[i-1]):
      obv.iloc[i] = obv.iloc[i-1] - X['volume'].iloc[i]
    else:
      obv.iloc[i] = obv.iloc[i-1]

  return obv

# %%
df['obv'] = obv(df)
df.head()
# Out:
#         high        low       open      close        avg         volume  \
# 0  82.885000  81.455000  82.255000  82.185000  82.107000  747272.000000
# 1  83.673889  82.188333  82.655000  83.325741  82.975889  642111.851852
# 2  84.649177  83.123251  84.084542  83.824389  83.897255  643383.938879
# 3  84.715710  83.081512  84.249820  83.501440  83.761213  698858.432731
# 4  83.999738  82.374817  83.736993  82.696778  82.940102  714359.058650
#
#    percentage_change  previous1  previous2  previous3  ...  previous5  \
# 0                NaN        NaN        NaN        NaN  ...        NaN
# 1           1.388016        NaN        NaN        NaN  ...        NaN
# 2           0.598432   1.388016        NaN        NaN  ...        NaN
# 3          -0.385269   0.598432   1.388016        NaN  ...        NaN
# 4          -0.963651  -0.385269   0.598432   1.388016  ...        NaN
#
#       ema50     ema21     ema14      ema5         rsi      macd  roc  atr  \
# 0  1.000000  1.000000  1.000000  1.000000         NaN  0.000000  NaN  NaN
# 1  1.006824  1.006731  1.006653  1.006262  100.000000  0.019890  NaN  NaN
# 2  1.008444  1.008268  1.008120  1.007388  100.000000  0.060000  NaN  NaN
# 3  1.003381  1.003206  1.003061  1.002375   83.542641  0.105115  NaN  NaN
# 4  0.995013  0.994947  0.994897  0.994735   59.247881  0.136880  NaN  NaN
#
#             obv
# 0  0.000000e+00
# 1  6.421119e+05
# 2  1.285496e+06
# 3  5.866374e+05
# 4 -1.277217e+05
#
# [5 rows x 21 columns]

# %%
def cmf(X, window=16):
  money_flow_multiplier = ((X['close'] - X['low']) - (X['high'] - X['close']))/(X['high']-X['low'])

  money_flow_volume = money_flow_multiplier * X['volume']

  cmf = money_flow_volume.rolling(window=window).sum() / X['volume'].rolling(window=window).sum()

  return cmf

# %%
df['cmf'] = cmf(df)
df.head()
# Out:
#         high        low       open      close        avg         volume  \
# 0  82.885000  81.455000  82.255000  82.185000  82.107000  747272.000000
# 1  83.673889  82.188333  82.655000  83.325741  82.975889  642111.851852
# 2  84.649177  83.123251  84.084542  83.824389  83.897255  643383.938879
# 3  84.715710  83.081512  84.249820  83.501440  83.761213  698858.432731
# 4  83.999738  82.374817  83.736993  82.696778  82.940102  714359.058650
#
#    percentage_change  previous1  previous2  previous3  ...     ema50  \
# 0                NaN        NaN        NaN        NaN  ...  1.000000
# 1           1.388016        NaN        NaN        NaN  ...  1.006824
# 2           0.598432   1.388016        NaN        NaN  ...  1.008444
# 3          -0.385269   0.598432   1.388016        NaN  ...  1.003381
# 4          -0.963651  -0.385269   0.598432   1.388016  ...  0.995013
#
#       ema21     ema14      ema5         rsi      macd  roc  atr           obv  \
# 0  1.000000  1.000000  1.000000         NaN  0.000000  NaN  NaN  0.000000e+00
# 1  1.006731  1.006653  1.006262  100.000000  0.019890  NaN  NaN  6.421119e+05
# 2  1.008268  1.008120  1.007388  100.000000  0.060000  NaN  NaN  1.285496e+06
# 3  1.003206  1.003061  1.002375   83.542641  0.105115  NaN  NaN  5.866374e+05
# 4  0.994947  0.994897  0.994735   59.247881  0.136880  NaN  NaN -1.277217e+05
#
#    cmf
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
# [5 rows x 22 columns]

# %%
def emv(X):
  emv = pd.Series(index=X.index)
  emv.iloc[0] = np.nan

  for i in range(1, len(X)):
    dm = 0.5 * ((X['high'].iloc[i] + X['low'].iloc[i]) - (X['high'].iloc[i-1] + X['low'].iloc[i-1]))
    br = X['volume'].iloc[i] / (1000000 * (X['high'].iloc[i] - X['low'].iloc[i]))
    emv.iloc[i] = dm / br if br != 0 else 0

  return emv

# %%
df['emv'] = emv(df)

# %%
df.head()
# Out:
#         high        low       open      close        avg         volume  \
# 0  82.885000  81.455000  82.255000  82.185000  82.107000  747272.000000
# 1  83.673889  82.188333  82.655000  83.325741  82.975889  642111.851852
# 2  84.649177  83.123251  84.084542  83.824389  83.897255  643383.938879
# 3  84.715710  83.081512  84.249820  83.501440  83.761213  698858.432731
# 4  83.999738  82.374817  83.736993  82.696778  82.940102  714359.058650
#
#    percentage_change  previous1  previous2  previous3  ...     ema21  \
# 0                NaN        NaN        NaN        NaN  ...  1.000000
# 1           1.388016        NaN        NaN        NaN  ...  1.006731
# 2           0.598432   1.388016        NaN        NaN  ...  1.008268
# 3          -0.385269   0.598432   1.388016        NaN  ...  1.003206
# 4          -0.963651  -0.385269   0.598432   1.388016  ...  0.994947
#
#       ema14      ema5         rsi      macd  roc  atr           obv  cmf  \
# 0  1.000000  1.000000         NaN  0.000000  NaN  NaN  0.000000e+00  NaN
# 1  1.006653  1.006262  100.000000  0.019890  NaN  NaN  6.421119e+05  NaN
# 2  1.008120  1.007388  100.000000  0.060000  NaN  NaN  1.285496e+06  NaN
# 3  1.003061  1.002375   83.542641  0.105115  NaN  NaN  5.866374e+05  NaN
# 4  0.994897  0.994735   59.247881  0.136880  NaN  NaN -1.277217e+05  NaN
#
#         emv
# 0       NaN
# 1  1.760866
# 2  2.265235
# 3  0.028989
# 4 -1.618038
#
# [5 rows x 23 columns]

# %%
window = 16

df['minimum_low'] = df['low'].rolling(window=window).min()
df['maximum_high'] = df['high'].rolling(window=window).max()
df['stoch'] = ((df['close'] - df['minimum_low']) / (df['maximum_high'] - df['minimum_low'])) * 100

# %%
df = df.drop(['minimum_low', 'maximum_high'], axis=1)
df.head()
# Out:
#         high        low       open      close        avg         volume  \
# 0  82.885000  81.455000  82.255000  82.185000  82.107000  747272.000000
# 1  83.673889  82.188333  82.655000  83.325741  82.975889  642111.851852
# 2  84.649177  83.123251  84.084542  83.824389  83.897255  643383.938879
# 3  84.715710  83.081512  84.249820  83.501440  83.761213  698858.432731
# 4  83.999738  82.374817  83.736993  82.696778  82.940102  714359.058650
#
#    percentage_change  previous1  previous2  previous3  ...     ema14  \
# 0                NaN        NaN        NaN        NaN  ...  1.000000
# 1           1.388016        NaN        NaN        NaN  ...  1.006653
# 2           0.598432   1.388016        NaN        NaN  ...  1.008120
# 3          -0.385269   0.598432   1.388016        NaN  ...  1.003061
# 4          -0.963651  -0.385269   0.598432   1.388016  ...  0.994897
#
#        ema5         rsi      macd  roc  atr           obv  cmf       emv  \
# 0  1.000000         NaN  0.000000  NaN  NaN  0.000000e+00  NaN       NaN
# 1  1.006262  100.000000  0.019890  NaN  NaN  6.421119e+05  NaN  1.760866
# 2  1.007388  100.000000  0.060000  NaN  NaN  1.285496e+06  NaN  2.265235
# 3  1.002375   83.542641  0.105115  NaN  NaN  5.866374e+05  NaN  0.028989
# 4  0.994735   59.247881  0.136880  NaN  NaN -1.277217e+05  NaN -1.618038
#
#    stoch
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#
# [5 rows x 24 columns]

# %%
def mfi(X, window=14):
  combine_price = (X['high'] + X['low'] + X['close']) / 3

  raw_money_flow = combine_price * X['volume']

  flow_direction = (combine_price.diff() > 0).astype(int)

  positive_money_flow = flow_direction * raw_money_flow
  negative_money_flow = (1 - flow_direction) * raw_money_flow

  positive = positive_money_flow.rolling(window=window, min_periods=1).sum()
  negative = negative_money_flow.rolling(window=window, min_periods=1).sum()

  mf = positive / negative
  mfi = 100 - (100 / (1 + mf))

  return mfi

# %%
df['mfi'] = mfi(df)
df.head()
# Out:
#         high        low       open      close        avg         volume  \
# 0  82.885000  81.455000  82.255000  82.185000  82.107000  747272.000000
# 1  83.673889  82.188333  82.655000  83.325741  82.975889  642111.851852
# 2  84.649177  83.123251  84.084542  83.824389  83.897255  643383.938879
# 3  84.715710  83.081512  84.249820  83.501440  83.761213  698858.432731
# 4  83.999738  82.374817  83.736993  82.696778  82.940102  714359.058650
#
#    percentage_change  previous1  previous2  previous3  ...      ema5  \
# 0                NaN        NaN        NaN        NaN  ...  1.000000
# 1           1.388016        NaN        NaN        NaN  ...  1.006262
# 2           0.598432   1.388016        NaN        NaN  ...  1.007388
# 3          -0.385269   0.598432   1.388016        NaN  ...  1.002375
# 4          -0.963651  -0.385269   0.598432   1.388016  ...  0.994735
#
#           rsi      macd  roc  atr           obv  cmf       emv  stoch  \
# 0         NaN  0.000000  NaN  NaN  0.000000e+00  NaN       NaN    NaN
# 1  100.000000  0.019890  NaN  NaN  6.421119e+05  NaN  1.760866    NaN
# 2  100.000000  0.060000  NaN  NaN  1.285496e+06  NaN  2.265235    NaN
# 3   83.542641  0.105115  NaN  NaN  5.866374e+05  NaN  0.028989    NaN
# 4   59.247881  0.136880  NaN  NaN -1.277217e+05  NaN -1.618038    NaN
#
#          mfi
# 0   0.000000
# 1  46.482753
# 2  63.599917
# 3  47.215621
# 4  37.443147
#
# [5 rows x 25 columns]

# %%
window = 21

df['combine_price'] = (df['high'] + df['low'] + df['close']) / 3
df['sma_combine_price'] = df['combine_price'].rolling(window=window).mean()
df['mean_deviation'] = df['combine_price'].rolling(window).apply(lambda x: x.mad())
df['cci'] = (df['combine_price'] - df['sma_combine_price']) / (0.015 * df['mean_deviation'])

# %%
df = df.drop(['combine_price', 'sma_combine_price', 'mean_deviation'], axis=1)
df.head()
# Out:
#         high        low       open      close        avg         volume  \
# 0  82.885000  81.455000  82.255000  82.185000  82.107000  747272.000000
# 1  83.673889  82.188333  82.655000  83.325741  82.975889  642111.851852
# 2  84.649177  83.123251  84.084542  83.824389  83.897255  643383.938879
# 3  84.715710  83.081512  84.249820  83.501440  83.761213  698858.432731
# 4  83.999738  82.374817  83.736993  82.696778  82.940102  714359.058650
#
#    percentage_change  previous1  previous2  previous3  ...         rsi  \
# 0                NaN        NaN        NaN        NaN  ...         NaN
# 1           1.388016        NaN        NaN        NaN  ...  100.000000
# 2           0.598432   1.388016        NaN        NaN  ...  100.000000
# 3          -0.385269   0.598432   1.388016        NaN  ...   83.542641
# 4          -0.963651  -0.385269   0.598432   1.388016  ...   59.247881
#
#        macd  roc  atr           obv  cmf       emv  stoch        mfi  cci
# 0  0.000000  NaN  NaN  0.000000e+00  NaN       NaN    NaN   0.000000  NaN
# 1  0.019890  NaN  NaN  6.421119e+05  NaN  1.760866    NaN  46.482753  NaN
# 2  0.060000  NaN  NaN  1.285496e+06  NaN  2.265235    NaN  63.599917  NaN
# 3  0.105115  NaN  NaN  5.866374e+05  NaN  0.028989    NaN  47.215621  NaN
# 4  0.136880  NaN  NaN -1.277217e+05  NaN -1.618038    NaN  37.443147  NaN
#
# [5 rows x 26 columns]

# %%
df['volume'] = df['volume'] / df['volume'].ewm(5).mean()
df.head()
# Out:
#         high        low       open      close        avg    volume  \
# 0  82.885000  81.455000  82.255000  82.185000  82.107000  1.000000
# 1  83.673889  82.188333  82.655000  83.325741  82.975889  0.930716
# 2  84.649177  83.123251  84.084542  83.824389  83.897255  0.958122
# 3  84.715710  83.081512  84.249820  83.501440  83.761213  1.027264
# 4  83.999738  82.374817  83.736993  82.696778  82.940102  1.035606
#
#    percentage_change  previous1  previous2  previous3  ...         rsi  \
# 0                NaN        NaN        NaN        NaN  ...         NaN
# 1           1.388016        NaN        NaN        NaN  ...  100.000000
# 2           0.598432   1.388016        NaN        NaN  ...  100.000000
# 3          -0.385269   0.598432   1.388016        NaN  ...   83.542641
# 4          -0.963651  -0.385269   0.598432   1.388016  ...   59.247881
#
#        macd  roc  atr           obv  cmf       emv  stoch        mfi  cci
# 0  0.000000  NaN  NaN  0.000000e+00  NaN       NaN    NaN   0.000000  NaN
# 1  0.019890  NaN  NaN  6.421119e+05  NaN  1.760866    NaN  46.482753  NaN
# 2  0.060000  NaN  NaN  1.285496e+06  NaN  2.265235    NaN  63.599917  NaN
# 3  0.105115  NaN  NaN  5.866374e+05  NaN  0.028989    NaN  47.215621  NaN
# 4  0.136880  NaN  NaN -1.277217e+05  NaN -1.618038    NaN  37.443147  NaN
#
# [5 rows x 26 columns]

# %%
df = df.rename(columns={'percentage_change': 'today'})
df.replace(0, np.nan, inplace=True)
df = df.dropna()
df.head()
# Out:
#          high        low       open      close        avg    volume     today  \
# 20  83.658320  82.418728  82.967830  83.123208  83.001338  1.103148  0.272851
# 21  83.847912  82.562555  83.160991  83.329123  83.176553  1.143207  0.247723
# 22  84.281519  82.833894  83.358597  83.306943  83.497619  1.102787 -0.026617
# 23  84.127782  82.564863  83.294509  83.243930  83.310992  1.106205 -0.075639
# 24  84.031724  82.275702  83.060828  83.176376  83.117427  1.447191 -0.081152
#
#     previous1  previous2  previous3  ...        rsi      macd       roc  \
# 20   0.411613   0.006285  -0.574878  ...  46.452205  0.126914  0.332011
# 21   0.272851   0.411613   0.006285  ...  48.777489  0.132547  0.284046
# 22   0.247723   0.272851   0.411613  ...  45.487265  0.142015  0.334349
# 23  -0.026617   0.247723   0.272851  ...  65.064461  0.152040  0.838154
# 24  -0.075639  -0.026617   0.247723  ...  72.918482  0.160423  0.749988
#
#          atr           obv       cmf       emv      stoch        mfi  \
# 20  1.565383  4.768241e+06  0.076565  0.417704  62.700835  50.921600
# 21  1.522179  5.835992e+06  0.082589  0.200685  69.289508  52.854204
# 22  1.498126  4.783966e+06  0.040306  0.485016  68.579821  54.614634
# 23  1.510839  3.705421e+06  0.025584 -0.306317  66.563593  52.384776
# 24  1.540680  2.153880e+06  0.022985 -0.217994  64.554787  48.337210
#
#           cci
# 20  27.843369
# 21  50.969611
# 22  82.153863
# 23  63.952689
# 24  46.214056
#
# [5 rows x 26 columns]

# %%
df['trend'] = (df['today'].iloc[:] > 0).astype(int)
df.head()
# Out:
#          high        low       open      close        avg    volume     today  \
# 20  83.658320  82.418728  82.967830  83.123208  83.001338  1.103148  0.272851
# 21  83.847912  82.562555  83.160991  83.329123  83.176553  1.143207  0.247723
# 22  84.281519  82.833894  83.358597  83.306943  83.497619  1.102787 -0.026617
# 23  84.127782  82.564863  83.294509  83.243930  83.310992  1.106205 -0.075639
# 24  84.031724  82.275702  83.060828  83.176376  83.117427  1.447191 -0.081152
#
#     previous1  previous2  previous3  ...      macd       roc       atr  \
# 20   0.411613   0.006285  -0.574878  ...  0.126914  0.332011  1.565383
# 21   0.272851   0.411613   0.006285  ...  0.132547  0.284046  1.522179
# 22   0.247723   0.272851   0.411613  ...  0.142015  0.334349  1.498126
# 23  -0.026617   0.247723   0.272851  ...  0.152040  0.838154  1.510839
# 24  -0.075639  -0.026617   0.247723  ...  0.160423  0.749988  1.540680
#
#              obv       cmf       emv      stoch        mfi        cci  trend
# 20  4.768241e+06  0.076565  0.417704  62.700835  50.921600  27.843369      1
# 21  5.835992e+06  0.082589  0.200685  69.289508  52.854204  50.969611      1
# 22  4.783966e+06  0.040306  0.485016  68.579821  54.614634  82.153863      0
# 23  3.705421e+06  0.025584 -0.306317  66.563593  52.384776  63.952689      0
# 24  2.153880e+06  0.022985 -0.217994  64.554787  48.337210  46.214056      0
#
# [5 rows x 27 columns]

# %%
df_stock = {}
df_stock = df[['volume', 'today', 'previous1', 'previous2', 'previous3', 'previous4', 'previous5',
          'ema50', 'ema21', 'ema14', 'ema5', 'rsi', 'macd', 'obv', 'emv', 'mfi', 'roc', 'atr', 'cmf', 'stoch', 'cci', 'trend']]
df_stock
# Out:
#         volume     today  previous1  previous2  previous3  previous4  \
# 20    1.103148  0.272851   0.411613   0.006285  -0.574878  -0.076739
# 21    1.143207  0.247723   0.272851   0.411613   0.006285  -0.574878
# 22    1.102787 -0.026617   0.247723   0.272851   0.411613   0.006285
# 23    1.106205 -0.075639  -0.026617   0.247723   0.272851   0.411613
# 24    1.447191 -0.081152  -0.075639  -0.026617   0.247723   0.272851
# ...        ...       ...        ...        ...        ...        ...
# 1738  0.871701  1.067019  -0.228837   0.098490   0.447074  -0.267450
# 1739  1.028413  0.829263   1.067019  -0.228837   0.098490   0.447074
# 1740  0.943041  0.220304   0.829263   1.067019  -0.228837   0.098490
# 1741  1.053903  0.256676   0.220304   0.829263   1.067019  -0.228837
# 1742  1.055481 -0.336182   0.256676   0.220304   0.829263   1.067019
#
#       previous5     ema50     ema21     ema14  ...      macd           obv  \
# 20     0.295670  1.002751  1.002948  1.003085  ...  0.126914  4.768241e+06
# 21    -0.076739  1.004943  1.005045  1.005092  ...  0.132547  5.835992e+06
# 22    -0.574878  1.004424  1.004445  1.004418  ...  0.142015  4.783966e+06
# 23     0.006285  1.003473  1.003436  1.003356  ...  0.152040  3.705421e+06
# 24     0.411613  1.002525  1.002448  1.002335  ...  0.160423  2.153880e+06
# ...         ...       ...       ...       ...  ...       ...           ...
# 1738  -1.208497  0.921946  0.982766  0.995525  ... -0.395080  3.074456e+08
# 1739  -0.267450  0.930876  0.991325  1.003528  ... -0.377402  3.129503e+08
# 1740   0.447074  0.934156  0.993802  1.005354  ... -0.348065  3.179412e+08
# 1741   0.098490  0.937720  0.996518  1.007402  ... -0.309535  3.235796e+08
# 1742  -0.228837  0.935768  0.993477  1.003746  ... -0.269898  3.178694e+08
#
#            emv        mfi       roc       atr       cmf      stoch        cci  \
# 20    0.417704  50.921600  0.332011  1.565383  0.076565  62.700835  27.843369
# 21    0.200685  52.854204  0.284046  1.522179  0.082589  69.289508  50.969611
# 22    0.485016  54.614634  0.334349  1.498126  0.040306  68.579821  82.153863
# 23   -0.306317  52.384776  0.838154  1.510839  0.025584  66.563593  63.952689
# 24   -0.217994  48.337210  0.749988  1.540680  0.022985  64.554787  46.214056
# ...        ...        ...       ...       ...       ...        ...        ...
# 1738  0.094754  57.626185 -0.106823  1.034749 -0.048672  43.672537 -14.611007
# 1739  0.101055  58.125553  1.953660  1.024553 -0.051005  59.117881  42.238120
# 1740  0.058046  57.059636  2.452277  1.013875 -0.055124  63.255158  67.619603
# 1741  0.008608  55.659520  2.258079  1.007903 -0.073406  68.086120  72.243002
# 1742  0.010682  47.954033  1.814030  0.990579 -0.126625  61.742533  63.945698
#
#       trend
# 20        1
# 21        1
# 22        0
# 23        0
# 24        0
# ...     ...
# 1738      1
# 1739      1
# 1740      1
# 1741      1
# 1742      0
#
# [1717 rows x 22 columns]

# %% [markdown]
# ## LSTM Model

# %%
X = df_stock.loc[:, df_stock.columns != ('trend')]
y = df_stock.loc[:, df_stock.columns == ('trend')]
scale = MinMaxScaler(feature_range=(0,1))
X_scaled = scale.fit_transform(X)

timesteps = 30
feature = X_scaled.shape[1]

test_len = int(len(X_scaled)*0.2)
train_len = X_scaled.shape[0] - test_len

X_train = []
y_train = []

for i in range(timesteps, train_len):
  X_train.append(X_scaled[i-timesteps:i,:])
  y_train.append(y.values[i,:])


X_train = np.asarray(X_train)
y_train = np.asarray(y_train)
print("X train dataset shape",X_train.shape)
print("y train dataset shape",y_train.shape)

X_test = []
y_test = []

for i in range(train_len-1, len(X_scaled)):
  X_test.append(X_scaled[i-timesteps: i, :])
  y_test.append(y.values[i,:])

X_test = np.asarray(X_test)
y_test = np.asarray(y_test)

print("X test dataset shape",X_test.shape)
print("y test dataset shape",y_test.shape)
# Out:
# X train dataset shape (1344, 30, 21)
# y train dataset shape (1344, 1)
# X test dataset shape (344, 30, 21)
# y test dataset shape (344, 1)

# %%
lstm_model = Sequential()
lstm_model.add(LSTM(128, return_sequences=True, input_shape=(timesteps, feature)))
lstm_model.add(LSTM(64, return_sequences=False))
lstm_model.add(Dense(1, activation='sigmoid'))
lstm_model.compile(optimizer='adam', loss='mse')

# %%
history = lstm_model.fit(X_train, y_train, epochs=30, batch_size=8)
# Out:
# Epoch 1/30
# 168/168 [==============================] - 8s 26ms/step - loss: 0.2491
# Epoch 2/30
# 168/168 [==============================] - 6s 36ms/step - loss: 0.2464
# Epoch 3/30
# 168/168 [==============================] - 5s 28ms/step - loss: 0.2458
# Epoch 4/30
# 168/168 [==============================] - 5s 28ms/step - loss: 0.2449
# Epoch 5/30
# 168/168 [==============================] - 5s 32ms/step - loss: 0.2445
# Epoch 6/30
# 168/168 [==============================] - 4s 25ms/step - loss: 0.2383
# Epoch 7/30
# 168/168 [==============================] - 5s 28ms/step - loss: 0.2295
# Epoch 8/30
# 168/168 [==============================] - 5s 32ms/step - loss: 0.2240
# Epoch 9/30
# 168/168 [==============================] - 5s 29ms/step - loss: 0.2218
# Epoch 10/30
# 168/168 [==============================] - 6s 33ms/step - loss: 0.2178
# Epoch 11/30
# 168/168 [==============================] - 5s 29ms/step - loss: 0.2165
# Epoch 12/30
# 168/168 [==============================] - 4s 26ms/step - loss: 0.2139
# Epoch 13/30
# 168/168 [==============================] - 6s 34ms/step - loss: 0.2161
# Epoch 14/30
# 168/168 [==============================] - 6s 38ms/step - loss: 0.2155
# Epoch 15/30
# 168/168 [==============================] - 5s 29ms/step - loss: 0.2129
# Epoch 16/30
# 168/168 [==============================] - 6s 34ms/step - loss: 0.2105
# Epoch 17/30
# 168/168 [==============================] - 5s 29ms/step - loss: 0.2196
# Epoch 18/30
# 168/168 [==============================] - 5s 31ms/step - loss: 0.2150
# Epoch 19/30
# 168/168 [==============================] - 5s 29ms/step - loss: 0.2115
# Epoch 20/30
# 168/168 [==============================] - 4s 25ms/step - loss: 0.2103
# Epoch 21/30
# 168/168 [==============================] - 6s 36ms/step - loss: 0.2121
# Epoch 22/30
# 168/168 [==============================] - 4s 26ms/step - loss: 0.2084
# Epoch 23/30
# 168/168 [==============================] - 4s 27ms/step - loss: 0.2066
# Epoch 24/30
# 168/168 [==============================] - 6s 33ms/step - loss: 0.2055
# Epoch 25/30
# 168/168 [==============================] - 4s 25ms/step - loss: 0.2060
# Epoch 26/30
# 168/168 [==============================] - 5s 27ms/step - loss: 0.2004
# Epoch 27/30
# 168/168 [==============================] - 6s 34ms/step - loss: 0.2020
# Epoch 28/30
# 168/168 [==============================] - 4s 27ms/step - loss: 0.2012
# Epoch 29/30
# 168/168 [==============================] - 4s 26ms/step - loss: 0.1935
# Epoch 30/30
# 168/168 [==============================] - 7s 41ms/step - loss: 0.1911

# %%
y_pred = lstm_model.predict(X_test, batch_size=8)
prediction = (y_pred > 0.5).astype(int)
# Out:
# 43/43 [==============================] - 1s 10ms/step

# %%
accuracy = accuracy_score(prediction, y_test)
classification_rep = classification_report(prediction, y_test)
print("Accuracy: ", accuracy)
print("Classification Report:\n", classification_rep)
# Out:
# Accuracy:  0.6366279069767442
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.72      0.61      0.66       201
#            1       0.55      0.67      0.61       143
#
#     accuracy                           0.64       344
#    macro avg       0.64      0.64      0.63       344
# weighted avg       0.65      0.64      0.64       344

# %% [markdown]
# ## Predict with new data

# %%
new_stock = {}
for i in range(len(stock_symbols)):
  data = dt.DataLoader(symbols=stock_symbols[i],
                        start="2024-01-01",
                        end="2024-03-01",
                        data_source="VND")
  new_stock[stock_symbols[i]] = data.download()

# %%
new_stock[stock_symbols[0]]
# Out:
# Attributes   high    low   open  close    avg      volume
# Symbols       VIC    VIC    VIC    VIC    VIC         VIC
# date
# 2024-01-02  44.95  44.00  44.95  44.00  44.35   2324300.0
# 2024-01-03  44.15  43.50  43.50  44.15  43.73   2347100.0
# 2024-01-04  44.40  43.80  44.15  44.15  44.14   2380800.0
# 2024-01-05  44.20  43.90  44.15  44.10  44.03   1553600.0
# 2024-01-08  44.75  44.10  44.45  44.35  44.43   2577400.0
# 2024-01-09  44.40  43.90  44.30  43.90  44.08   1716800.0
# 2024-01-10  44.05  43.20  43.90  43.60  43.65   2718700.0
# 2024-01-11  44.00  43.40  43.60  43.65  43.77   1758100.0
# 2024-01-12  43.50  42.70  43.50  43.00  43.03   3009600.0
# 2024-01-15  43.50  43.05  43.50  43.05  43.21   1528300.0
# 2024-01-16  43.25  42.85  43.00  43.15  43.00   1479500.0
# 2024-01-17  43.45  42.95  43.15  43.20  43.21   1950300.0
# 2024-01-18  43.50  43.00  43.00  43.35  43.24   1768100.0
# 2024-01-19  43.45  43.15  43.35  43.30  43.29   2977400.0
# 2024-01-22  43.50  43.15  43.50  43.30  43.29   1754900.0
# 2024-01-23  43.40  42.90  43.40  43.10  43.06   2283000.0
# 2024-01-24  43.25  42.90  43.20  43.15  43.06   3073500.0
# 2024-01-25  43.10  42.80  43.10  42.80  42.89   3222300.0
# 2024-01-26  43.00  42.65  42.70  42.80  42.79   8010463.0
# 2024-01-29  42.85  42.40  42.80  42.65  42.63   7711400.0
# 2024-01-30  42.80  42.50  42.65  42.70  42.59   6472900.0
# 2024-01-31  42.80  42.10  42.70  42.50  42.47   2833900.0
# 2024-02-01  42.50  42.05  42.45  42.35  42.18   2216100.0
# 2024-02-02  42.50  42.05  42.35  42.10  42.15   4026500.0
# 2024-02-05  42.20  41.80  42.20  42.20  42.00   3109400.0
# 2024-02-06  42.35  41.90  42.25  42.30  42.07   1779700.0
# 2024-02-07  42.40  42.00  42.30  42.40  42.24   1616000.0
# 2024-02-15  42.80  42.20  42.50  42.55  42.53   2049700.0
# 2024-02-16  44.15  42.50  42.55  43.95  43.64   5012200.0
# 2024-02-19  47.00  44.30  44.30  47.00  46.42  16751900.0
# 2024-02-20  49.35  47.90  48.00  48.50  48.81   8994900.0
# 2024-02-21  48.55  47.10  48.55  47.25  47.59  10914000.0
# 2024-02-22  47.70  47.00  47.25  47.60  47.43   4175500.0
# 2024-02-23  47.95  45.20  47.95  45.20  46.46  16212200.0
# 2024-02-26  45.75  44.30  45.35  44.60  44.88   5204400.0
# 2024-02-27  45.65  44.35  44.80  45.15  44.79   4462500.0
# 2024-02-28  46.40  45.25  45.90  45.60  45.79   3389700.0
# 2024-02-29  46.15  45.00  46.00  45.00  45.43   5625800.0
# 2024-03-01  45.60  44.85  45.00  45.25  45.17   3002700.0

# %%
for i in range(len(stock_symbols)):
  print(f"Length of {stock_symbols[i]} with index {i}: ", len(new_stock[stock_symbols[i]]))
# Out:
# Length of VIC with index 0:  39
# Length of VCB with index 1:  39
# Length of VNM with index 2:  39
# Length of GAS with index 3:  39
# Length of HVN with index 4:  39
# Length of MWG with index 5:  39
# Length of FPT with index 6:  39
# Length of HPG with index 7:  39
# Length of MSN with index 8:  39
# Length of SAB with index 9:  39

# %%
combined_new_high = (new_stock[stock_symbols[0]]['high'].values + new_stock[stock_symbols[1]]['high'].values + new_stock[stock_symbols[2]]['high'].values +
                 new_stock[stock_symbols[3]]['high'].values + new_stock[stock_symbols[4]]['high'].values + new_stock[stock_symbols[5]]['high'].values +
                 new_stock[stock_symbols[6]]['high'].values + new_stock[stock_symbols[7]]['high'].values + new_stock[stock_symbols[8]]['high'].values +
                 new_stock[stock_symbols[9]]['high'].values) / len(stock_symbols)
combined_new_high[:5]
# Out:
# array([[58.775],
#        [58.71 ],
#        [59.3  ],
#        [59.065],
#        [59.24 ]])

# %%
combined_new_low = (new_stock[stock_symbols[0]]['low'].values + new_stock[stock_symbols[1]]['low'].values + new_stock[stock_symbols[2]]['low'].values +
                 new_stock[stock_symbols[3]]['low'].values + new_stock[stock_symbols[4]]['low'].values + new_stock[stock_symbols[5]]['low'].values +
                 new_stock[stock_symbols[6]]['low'].values + new_stock[stock_symbols[7]]['low'].values + new_stock[stock_symbols[8]]['low'].values +
                 new_stock[stock_symbols[9]]['low'].values) / len(stock_symbols)
combined_new_low[:5]
# Out:
# array([[57.69 ],
#        [57.765],
#        [58.295],
#        [58.305],
#        [58.425]])

# %%
combined_new_open = (new_stock[stock_symbols[0]]['open'].values + new_stock[stock_symbols[1]]['open'].values + new_stock[stock_symbols[2]]['open'].values +
                 new_stock[stock_symbols[3]]['open'].values + new_stock[stock_symbols[4]]['open'].values + new_stock[stock_symbols[5]]['open'].values +
                 new_stock[stock_symbols[6]]['open'].values + new_stock[stock_symbols[7]]['open'].values + new_stock[stock_symbols[8]]['open'].values +
                 new_stock[stock_symbols[9]]['open'].values) / len(stock_symbols)
combined_new_open[:5]
# Out:
# array([[58.38 ],
#        [58.05 ],
#        [58.535],
#        [58.825],
#        [58.935]])

# %%
combined_new_close = (new_stock[stock_symbols[0]]['close'].values + new_stock[stock_symbols[1]]['close'].values + new_stock[stock_symbols[2]]['close'].values +
                 new_stock[stock_symbols[3]]['close'].values + new_stock[stock_symbols[4]]['close'].values + new_stock[stock_symbols[5]]['close'].values +
                 new_stock[stock_symbols[6]]['close'].values + new_stock[stock_symbols[7]]['close'].values + new_stock[stock_symbols[8]]['close'].values +
                 new_stock[stock_symbols[9]]['close'].values) / len(stock_symbols)
combined_new_close[:5]
# Out:
# array([[58.135],
#        [58.645],
#        [58.745],
#        [58.79 ],
#        [58.575]])

# %%
combined_new_avg = (new_stock[stock_symbols[0]]['avg'].values + new_stock[stock_symbols[1]]['avg'].values + new_stock[stock_symbols[2]]['avg'].values +
                 new_stock[stock_symbols[3]]['avg'].values + new_stock[stock_symbols[4]]['avg'].values + new_stock[stock_symbols[5]]['avg'].values +
                 new_stock[stock_symbols[6]]['avg'].values + new_stock[stock_symbols[7]]['avg'].values + new_stock[stock_symbols[8]]['avg'].values +
                 new_stock[stock_symbols[9]]['avg'].values) / len(stock_symbols)
combined_new_avg[:5]
# Out:
# array([[58.192],
#        [58.293],
#        [58.806],
#        [58.646],
#        [58.766]])

# %%
combined_new_volume = (new_stock[stock_symbols[0]]['volume'].values + new_stock[stock_symbols[1]]['volume'].values + new_stock[stock_symbols[2]]['volume'].values +
                 new_stock[stock_symbols[3]]['volume'].values + new_stock[stock_symbols[4]]['volume'].values + new_stock[stock_symbols[5]]['volume'].values +
                 new_stock[stock_symbols[6]]['volume'].values + new_stock[stock_symbols[7]]['volume'].values + new_stock[stock_symbols[8]]['volume'].values +
                 new_stock[stock_symbols[9]]['volume'].values) / len(stock_symbols)
combined_new_volume[:5]
# Out:
# array([[4590397.6],
#        [4504060. ],
#        [6850260. ],
#        [4142200. ],
#        [5685750. ]])

# %%
df_new_stock = pd.DataFrame(combined_new_high)
df_new_stock.head()
# Out:
#         0
# 0  58.775
# 1  58.710
# 2  59.300
# 3  59.065
# 4  59.240

# %%
df_new_stock = df_new_stock.rename(columns={0: 'high'})

df_new_stock['low'] = combined_new_low
df_new_stock['open'] = combined_new_open
df_new_stock['close'] = combined_new_close
df_new_stock['avg'] = combined_new_avg
df_new_stock['volume'] = combined_new_volume

df_new_stock.head()
# Out:
#      high     low    open   close     avg     volume
# 0  58.775  57.690  58.380  58.135  58.192  4590397.6
# 1  58.710  57.765  58.050  58.645  58.293  4504060.0
# 2  59.300  58.295  58.535  58.745  58.806  6850260.0
# 3  59.065  58.305  58.825  58.790  58.646  4142200.0
# 4  59.240  58.425  58.935  58.575  58.766  5685750.0

# %%
df_new_stock = df_new_stock.ewm(alpha=0.65).mean()
df_new_stock.head()
# Out:
#         high        low       open      close        avg        volume
# 0  58.775000  57.690000  58.380000  58.135000  58.192000  4.590398e+06
# 1  58.726852  57.745556  58.135556  58.512778  58.266815  4.526444e+06
# 2  59.116087  58.118693  58.406825  58.670484  58.632985  6.104587e+06
# 3  59.082374  58.241637  58.682780  58.749353  58.641574  4.809603e+06
# 4  59.185372  58.361452  58.847589  58.635425  58.722878  5.382105e+06

# %%
df_new_stock['percentage_change'] = df_new_stock['close'].pct_change() * 100
df_new_stock.head()
# Out:
#         high        low       open      close        avg        volume  \
# 0  58.775000  57.690000  58.380000  58.135000  58.192000  4.590398e+06
# 1  58.726852  57.745556  58.135556  58.512778  58.266815  4.526444e+06
# 2  59.116087  58.118693  58.406825  58.670484  58.632985  6.104587e+06
# 3  59.082374  58.241637  58.682780  58.749353  58.641574  4.809603e+06
# 4  59.185372  58.361452  58.847589  58.635425  58.722878  5.382105e+06
#
#    percentage_change
# 0                NaN
# 1           0.649828
# 2           0.269524
# 3           0.134427
# 4          -0.193922

# %%
for i in range(1, 6):
  df_new_stock[f'previous{str(i)}'] = df_new_stock['percentage_change'].shift(i)

df_new_stock.head()
# Out:
#         high        low       open      close        avg        volume  \
# 0  58.775000  57.690000  58.380000  58.135000  58.192000  4.590398e+06
# 1  58.726852  57.745556  58.135556  58.512778  58.266815  4.526444e+06
# 2  59.116087  58.118693  58.406825  58.670484  58.632985  6.104587e+06
# 3  59.082374  58.241637  58.682780  58.749353  58.641574  4.809603e+06
# 4  59.185372  58.361452  58.847589  58.635425  58.722878  5.382105e+06
#
#    percentage_change  previous1  previous2  previous3  previous4  previous5
# 0                NaN        NaN        NaN        NaN        NaN        NaN
# 1           0.649828        NaN        NaN        NaN        NaN        NaN
# 2           0.269524   0.649828        NaN        NaN        NaN        NaN
# 3           0.134427   0.269524   0.649828        NaN        NaN        NaN
# 4          -0.193922   0.134427   0.269524   0.649828        NaN        NaN

# %%
df_new_stock['ema50'] = df_new_stock['close'] / df_new_stock['close'].ewm(50).mean()
df_new_stock['ema21'] = df_new_stock['close'] / df_new_stock['close'].ewm(21).mean()
df_new_stock['ema14'] = df_new_stock['close'] / df_new_stock['close'].ewm(14).mean()
df_new_stock['ema5'] = df_new_stock['close'] / df_new_stock['close'].ewm(5).mean()

df_new_stock.head()
# Out:
#         high        low       open      close        avg        volume  \
# 0  58.775000  57.690000  58.380000  58.135000  58.192000  4.590398e+06
# 1  58.726852  57.745556  58.135556  58.512778  58.266815  4.526444e+06
# 2  59.116087  58.118693  58.406825  58.670484  58.632985  6.104587e+06
# 3  59.082374  58.241637  58.682780  58.749353  58.641574  4.809603e+06
# 4  59.185372  58.361452  58.847589  58.635425  58.722878  5.382105e+06
#
#    percentage_change  previous1  previous2  previous3  previous4  previous5  \
# 0                NaN        NaN        NaN        NaN        NaN        NaN
# 1           0.649828        NaN        NaN        NaN        NaN        NaN
# 2           0.269524   0.649828        NaN        NaN        NaN        NaN
# 3           0.134427   0.269524   0.649828        NaN        NaN        NaN
# 4          -0.193922   0.134427   0.269524   0.649828        NaN        NaN
#
#       ema50     ema21     ema14      ema5
# 0  1.000000  1.000000  1.000000  1.000000
# 1  1.003206  1.003163  1.003127  1.002943
# 2  1.003893  1.003812  1.003744  1.003405
# 3  1.003888  1.003774  1.003680  1.003219
# 4  1.001537  1.001427  1.001337  1.000918

# %%
df_new_stock['rsi'] = rsi(df_new_stock['close'])
df_new_stock['macd'] = macd(df_new_stock['close'])
df_new_stock['obv'] = obv(df_new_stock)
df_new_stock['cmf'] = cmf(df_new_stock)
df_new_stock['emv'] = emv(df_new_stock)
df_new_stock['mfi'] = mfi(df_new_stock)

# %%
df_new_stock.head()
# Out:
#         high        low       open      close        avg        volume  \
# 0  58.775000  57.690000  58.380000  58.135000  58.192000  4.590398e+06
# 1  58.726852  57.745556  58.135556  58.512778  58.266815  4.526444e+06
# 2  59.116087  58.118693  58.406825  58.670484  58.632985  6.104587e+06
# 3  59.082374  58.241637  58.682780  58.749353  58.641574  4.809603e+06
# 4  59.185372  58.361452  58.847589  58.635425  58.722878  5.382105e+06
#
#    percentage_change  previous1  previous2  previous3  ...     ema50  \
# 0                NaN        NaN        NaN        NaN  ...  1.000000
# 1           0.649828        NaN        NaN        NaN  ...  1.003206
# 2           0.269524   0.649828        NaN        NaN  ...  1.003893
# 3           0.134427   0.269524   0.649828        NaN  ...  1.003888
# 4          -0.193922   0.134427   0.269524   0.649828  ...  1.001537
#
#       ema21     ema14      ema5         rsi      macd           obv  cmf  \
# 0  1.000000  1.000000  1.000000         NaN  0.000000  0.000000e+00  NaN
# 1  1.003163  1.003127  1.002943  100.000000  0.006587  4.526444e+06  NaN
# 2  1.003812  1.003744  1.003405  100.000000  0.019741  1.063103e+07  NaN
# 3  1.003774  1.003680  1.003219  100.000000  0.037717  1.544063e+07  NaN
# 4  1.001427  1.001337  1.000918   84.356615  0.055772  1.005853e+07  NaN
#
#         emv        mfi
# 0       NaN   0.000000
# 1  0.000803  49.704344
# 2  0.062280  69.952331
# 3  0.007799  77.193109
# 4  0.017055  82.039376
#
# [5 rows x 22 columns]

# %%
window = 6
df_new_stock['roc'] = ((df_new_stock['close'] - df_new_stock['close'].shift(window)) / df_new_stock['close'].shift(window)) * 100

df_new_stock.head()
# Out:
#         high        low       open      close        avg        volume  \
# 0  58.775000  57.690000  58.380000  58.135000  58.192000  4.590398e+06
# 1  58.726852  57.745556  58.135556  58.512778  58.266815  4.526444e+06
# 2  59.116087  58.118693  58.406825  58.670484  58.632985  6.104587e+06
# 3  59.082374  58.241637  58.682780  58.749353  58.641574  4.809603e+06
# 4  59.185372  58.361452  58.847589  58.635425  58.722878  5.382105e+06
#
#    percentage_change  previous1  previous2  previous3  ...     ema21  \
# 0                NaN        NaN        NaN        NaN  ...  1.000000
# 1           0.649828        NaN        NaN        NaN  ...  1.003163
# 2           0.269524   0.649828        NaN        NaN  ...  1.003812
# 3           0.134427   0.269524   0.649828        NaN  ...  1.003774
# 4          -0.193922   0.134427   0.269524   0.649828  ...  1.001427
#
#       ema14      ema5         rsi      macd           obv  cmf       emv  \
# 0  1.000000  1.000000         NaN  0.000000  0.000000e+00  NaN       NaN
# 1  1.003127  1.002943  100.000000  0.006587  4.526444e+06  NaN  0.000803
# 2  1.003744  1.003405  100.000000  0.019741  1.063103e+07  NaN  0.062280
# 3  1.003680  1.003219  100.000000  0.037717  1.544063e+07  NaN  0.007799
# 4  1.001337  1.000918   84.356615  0.055772  1.005853e+07  NaN  0.017055
#
#          mfi  roc
# 0   0.000000  NaN
# 1  49.704344  NaN
# 2  69.952331  NaN
# 3  77.193109  NaN
# 4  82.039376  NaN
#
# [5 rows x 23 columns]

# %%
window = 16

df_new_stock['high-low'] = df_new_stock['high'] - df_new_stock['low']
df_new_stock['high-preclose'] = abs(df_new_stock['high'] - df_new_stock['close'].shift(1))
df_new_stock['low-preclose'] = abs(df_new_stock['low'] - df_new_stock['close'].shift(1))
df_new_stock['tr'] = df_new_stock[[('high-low'), ('high-preclose'), ('low-preclose')]].max(axis=1)
df_new_stock['atr'] = df_new_stock['tr'].rolling(window=window).mean()

# %%
df_new_stock = df_new_stock.drop(['high-low', 'high-preclose', 'low-preclose', 'tr'], axis=1)

df_new_stock.head()
# Out:
#         high        low       open      close        avg        volume  \
# 0  58.775000  57.690000  58.380000  58.135000  58.192000  4.590398e+06
# 1  58.726852  57.745556  58.135556  58.512778  58.266815  4.526444e+06
# 2  59.116087  58.118693  58.406825  58.670484  58.632985  6.104587e+06
# 3  59.082374  58.241637  58.682780  58.749353  58.641574  4.809603e+06
# 4  59.185372  58.361452  58.847589  58.635425  58.722878  5.382105e+06
#
#    percentage_change  previous1  previous2  previous3  ...     ema14  \
# 0                NaN        NaN        NaN        NaN  ...  1.000000
# 1           0.649828        NaN        NaN        NaN  ...  1.003127
# 2           0.269524   0.649828        NaN        NaN  ...  1.003744
# 3           0.134427   0.269524   0.649828        NaN  ...  1.003680
# 4          -0.193922   0.134427   0.269524   0.649828  ...  1.001337
#
#        ema5         rsi      macd           obv  cmf       emv        mfi  \
# 0  1.000000         NaN  0.000000  0.000000e+00  NaN       NaN   0.000000
# 1  1.002943  100.000000  0.006587  4.526444e+06  NaN  0.000803  49.704344
# 2  1.003405  100.000000  0.019741  1.063103e+07  NaN  0.062280  69.952331
# 3  1.003219  100.000000  0.037717  1.544063e+07  NaN  0.007799  77.193109
# 4  1.000918   84.356615  0.055772  1.005853e+07  NaN  0.017055  82.039376
#
#    roc  atr
# 0  NaN  NaN
# 1  NaN  NaN
# 2  NaN  NaN
# 3  NaN  NaN
# 4  NaN  NaN
#
# [5 rows x 24 columns]

# %%
window = 16

df_new_stock['minimum_low'] = df_new_stock['low'].rolling(window=window).min()
df_new_stock['maximum_high'] = df_new_stock['high'].rolling(window=window).max()
df_new_stock['stoch'] = ((df_new_stock['close'] - df_new_stock['minimum_low']) / (df_new_stock['maximum_high'] - df_new_stock['minimum_low'])) * 100

# %%
df_new_stock = df_new_stock.drop(['minimum_low', 'maximum_high'], axis=1)
df_new_stock.head()
# Out:
#         high        low       open      close        avg        volume  \
# 0  58.775000  57.690000  58.380000  58.135000  58.192000  4.590398e+06
# 1  58.726852  57.745556  58.135556  58.512778  58.266815  4.526444e+06
# 2  59.116087  58.118693  58.406825  58.670484  58.632985  6.104587e+06
# 3  59.082374  58.241637  58.682780  58.749353  58.641574  4.809603e+06
# 4  59.185372  58.361452  58.847589  58.635425  58.722878  5.382105e+06
#
#    percentage_change  previous1  previous2  previous3  ...      ema5  \
# 0                NaN        NaN        NaN        NaN  ...  1.000000
# 1           0.649828        NaN        NaN        NaN  ...  1.002943
# 2           0.269524   0.649828        NaN        NaN  ...  1.003405
# 3           0.134427   0.269524   0.649828        NaN  ...  1.003219
# 4          -0.193922   0.134427   0.269524   0.649828  ...  1.000918
#
#           rsi      macd           obv  cmf       emv        mfi  roc  atr  \
# 0         NaN  0.000000  0.000000e+00  NaN       NaN   0.000000  NaN  NaN
# 1  100.000000  0.006587  4.526444e+06  NaN  0.000803  49.704344  NaN  NaN
# 2  100.000000  0.019741  1.063103e+07  NaN  0.062280  69.952331  NaN  NaN
# 3  100.000000  0.037717  1.544063e+07  NaN  0.007799  77.193109  NaN  NaN
# 4   84.356615  0.055772  1.005853e+07  NaN  0.017055  82.039376  NaN  NaN
#
#    stoch
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#
# [5 rows x 25 columns]

# %%
window = 21

df_new_stock['combine_price'] = (df_new_stock['high'] + df_new_stock['low'] + df_new_stock['close']) / 3
df_new_stock['sma_combine_price'] = df_new_stock['combine_price'].rolling(window=window).mean()
df_new_stock['mean_deviation'] = df_new_stock['combine_price'].rolling(window).apply(lambda x: x.mad())
df_new_stock['cci'] = (df_new_stock['combine_price'] - df_new_stock['sma_combine_price']) / (0.015 * df_new_stock['mean_deviation'])

# %%
df_new_stock = df_new_stock.drop(['combine_price', 'sma_combine_price', 'mean_deviation'], axis=1)
df_new_stock.head()
# Out:
#         high        low       open      close        avg        volume  \
# 0  58.775000  57.690000  58.380000  58.135000  58.192000  4.590398e+06
# 1  58.726852  57.745556  58.135556  58.512778  58.266815  4.526444e+06
# 2  59.116087  58.118693  58.406825  58.670484  58.632985  6.104587e+06
# 3  59.082374  58.241637  58.682780  58.749353  58.641574  4.809603e+06
# 4  59.185372  58.361452  58.847589  58.635425  58.722878  5.382105e+06
#
#    percentage_change  previous1  previous2  previous3  ...         rsi  \
# 0                NaN        NaN        NaN        NaN  ...         NaN
# 1           0.649828        NaN        NaN        NaN  ...  100.000000
# 2           0.269524   0.649828        NaN        NaN  ...  100.000000
# 3           0.134427   0.269524   0.649828        NaN  ...  100.000000
# 4          -0.193922   0.134427   0.269524   0.649828  ...   84.356615
#
#        macd           obv  cmf       emv        mfi  roc  atr  stoch  cci
# 0  0.000000  0.000000e+00  NaN       NaN   0.000000  NaN  NaN    NaN  NaN
# 1  0.006587  4.526444e+06  NaN  0.000803  49.704344  NaN  NaN    NaN  NaN
# 2  0.019741  1.063103e+07  NaN  0.062280  69.952331  NaN  NaN    NaN  NaN
# 3  0.037717  1.544063e+07  NaN  0.007799  77.193109  NaN  NaN    NaN  NaN
# 4  0.055772  1.005853e+07  NaN  0.017055  82.039376  NaN  NaN    NaN  NaN
#
# [5 rows x 26 columns]

# %%
df_new_stock['volume'] = df_new_stock['volume'] / df_new_stock['volume'].ewm(5).mean()
df_new_stock.head()
# Out:
#         high        low       open      close        avg    volume  \
# 0  58.775000  57.690000  58.380000  58.135000  58.192000  1.000000
# 1  58.726852  57.745556  58.135556  58.512778  58.266815  0.993619
# 2  59.116087  58.118693  58.406825  58.670484  58.632985  1.181152
# 3  59.082374  58.241637  58.682780  58.749353  58.641574  0.951858
# 4  59.185372  58.361452  58.847589  58.635425  58.722878  1.046166
#
#    percentage_change  previous1  previous2  previous3  ...         rsi  \
# 0                NaN        NaN        NaN        NaN  ...         NaN
# 1           0.649828        NaN        NaN        NaN  ...  100.000000
# 2           0.269524   0.649828        NaN        NaN  ...  100.000000
# 3           0.134427   0.269524   0.649828        NaN  ...  100.000000
# 4          -0.193922   0.134427   0.269524   0.649828  ...   84.356615
#
#        macd           obv  cmf       emv        mfi  roc  atr  stoch  cci
# 0  0.000000  0.000000e+00  NaN       NaN   0.000000  NaN  NaN    NaN  NaN
# 1  0.006587  4.526444e+06  NaN  0.000803  49.704344  NaN  NaN    NaN  NaN
# 2  0.019741  1.063103e+07  NaN  0.062280  69.952331  NaN  NaN    NaN  NaN
# 3  0.037717  1.544063e+07  NaN  0.007799  77.193109  NaN  NaN    NaN  NaN
# 4  0.055772  1.005853e+07  NaN  0.017055  82.039376  NaN  NaN    NaN  NaN
#
# [5 rows x 26 columns]

# %%
df_new_stock = df_new_stock.rename(columns={'percentage_change': 'today'})
df_new_stock.replace(0, np.nan, inplace=True)
df_new_stock = df_new_stock.dropna()
df_new_stock.head()
# Out:
#          high        low       open      close        avg    volume     today  \
# 20  58.542464  57.871097  58.225648  58.193780  58.183620  0.896113 -0.028011
# 21  58.527862  57.561634  58.247977  57.746073  58.004467  1.043712 -0.769338
# 22  58.617002  57.463072  57.768292  58.180876  58.129613  0.937985  0.752956
# 23  58.888701  57.909575  58.237402  58.518306  58.427565  0.957534  0.579969
# 24  59.110545  58.215351  58.544591  58.733907  58.674198  0.924709  0.368433
#
#     previous1  previous2  previous3  ...        rsi      macd           obv  \
# 20  -0.064038  -0.214389  -0.340944  ...  51.058511  0.090517 -8.494694e+04
# 21  -0.028011  -0.064038  -0.214389  ...  42.941962  0.069902 -4.985003e+06
# 22  -0.769338  -0.028011  -0.064038  ...  55.946389  0.051474 -6.362485e+05
# 23   0.752956  -0.769338  -0.028011  ...  59.149198  0.041131  3.765186e+06
# 24   0.579969   0.752956  -0.769338  ...  57.852822  0.040092  7.951890e+06
#
#          cmf       emv        mfi       roc       atr      stoch         cci
# 20 -0.137349 -0.016232  44.424334 -1.560265  0.834200  35.444452  -60.312614
# 21 -0.147509 -0.031951  43.940832 -1.976856  0.845696  14.542379 -117.485860
# 22 -0.109529 -0.001250  50.937147 -0.668154  0.854789  34.841994  -77.056360
# 23 -0.082901  0.079884  51.239443  0.249735  0.862848  50.595620    7.833178
# 24 -0.059108  0.056407  50.890086  0.835268  0.857340  60.131143   68.044556
#
# [5 rows x 26 columns]

# %%
df_new_stock['trend'] = (df_new_stock['today'].iloc[:] > 0).astype(int)
df_new_stock
# Out:
#          high        low       open      close        avg    volume     today  \
# 20  58.542464  57.871097  58.225648  58.193780  58.183620  0.896113 -0.028011
# 21  58.527862  57.561634  58.247977  57.746073  58.004467  1.043712 -0.769338
# 22  58.617002  57.463072  57.768292  58.180876  58.129613  0.937985  0.752956
# 23  58.888701  57.909575  58.237402  58.518306  58.427565  0.957534  0.579969
# 24  59.110545  58.215351  58.544591  58.733907  58.674198  0.924709  0.368433
# 25  59.240191  58.432873  58.840607  58.838618  58.784569  0.914830  0.178279
# 26  59.285567  58.580506  58.957212  58.979266  58.911599  0.833329  0.239041
# 27  59.515948  58.684177  59.098774  59.002493  59.032110  1.201855  0.039382
# 28  59.846832  58.821212  59.122321  59.468873  59.351838  1.115363  0.790440
# 29  60.836891  59.398924  59.709062  60.402355  60.190443  1.580469  1.569700
# 30  61.371912  60.101623  60.645672  60.813574  60.706905  1.225941  0.680800
# 31  61.406419  60.201318  60.921485  60.743001  60.666667  1.190345 -0.116049
# 32  61.252747  60.184211  60.774270  60.507050  60.609033  1.036764 -0.388441
# 33  61.172961  59.619224  60.638244  59.790718  60.350312  1.271597 -1.183883
# 34  60.618536  59.187478  59.865886  59.832501  59.882759  1.062242  0.069883
# 35  60.856738  59.442617  59.972560  60.295625  60.191666  1.511513  0.774035
# 36  61.593358  59.993416  60.516896  61.159719  60.851633  1.216711  1.433095
# 37  62.471925  60.966196  61.545914  61.670152  61.709872  1.138291  0.834590
# 38  62.594174  61.306668  61.967820  61.998303  61.958255  0.986391  0.532107
#
#     previous1  previous2  previous3  ...      macd           obv       cmf  \
# 20  -0.064038  -0.214389  -0.340944  ...  0.090517 -8.494694e+04 -0.137349
# 21  -0.028011  -0.064038  -0.214389  ...  0.069902 -4.985003e+06 -0.147509
# 22  -0.769338  -0.028011  -0.064038  ...  0.051474 -6.362485e+05 -0.109529
# 23   0.752956  -0.769338  -0.028011  ...  0.041131  3.765186e+06 -0.082901
# 24   0.579969   0.752956  -0.769338  ...  0.040092  7.951890e+06 -0.059108
# 25   0.368433   0.579969   0.752956  ...  0.046727  1.202377e+07 -0.047955
# 26   0.178279   0.368433   0.579969  ...  0.060232  1.561222e+07 -0.073763
# 27   0.239041   0.178279   0.368433  ...  0.077682  2.100699e+07 -0.098112
# 28   0.039382   0.239041   0.178279  ...  0.104718  2.613250e+07 -0.086334
# 29   0.790440   0.039382   0.239041  ...  0.152514  3.435476e+07 -0.056902
# 30   1.569700   0.790440   0.039382  ...  0.217881  4.103579e+07 -0.045289
# 31   0.680800   1.569700   0.790440  ...  0.289387  3.429108e+07 -0.040282
# 32  -0.116049   0.680800   1.569700  ...  0.356470  2.837294e+07 -0.039201
# 33  -0.388441  -0.116049   0.680800  ...  0.404166  2.069630e+07 -0.091854
# 34  -1.183883  -0.388441  -0.116049  ...  0.437116  2.719006e+07 -0.075244
# 35   0.069883  -1.183883  -0.388441  ...  0.466272  3.748536e+07 -0.035564
# 36   0.774035   0.069883  -1.183883  ...  0.505675  4.614871e+07  0.008779
# 37   1.433095   0.774035   0.069883  ...  0.557435  5.448451e+07  0.033319
# 38   0.834590   1.433095   0.774035  ...  0.618978  6.168830e+07  0.027292
#
#          emv        mfi       roc       atr      stoch         cci  trend
# 20 -0.016232  44.424334 -1.560265  0.834200  35.444452  -60.312614      0
# 21 -0.031951  43.940832 -1.976856  0.845696  14.542379 -117.485860      0
# 22 -0.001250  50.937147 -0.668154  0.854789  34.841994  -77.056360      1
# 23  0.079884  51.239443  0.249735  0.862848  50.595620    7.833178      1
# 24  0.056407  50.890086  0.835268  0.857340  60.131143   68.044556      1
# 25  0.034416  50.230276  1.079766  0.857241  65.085640  101.326029      1
# 26  0.018961  49.934407  1.349777  0.846847  71.740602  114.408419      1
# 27  0.025752  50.800286  2.175767  0.844428  72.839617  121.396299      1
# 28  0.046815  49.243286  2.213781  0.865518  84.144405  154.808103      1
# 29  0.137092  59.939262  3.219589  0.894838  87.120360  248.476395      1
# 30  0.117666  68.122889  3.540829  0.917693  85.716030  265.620076      1
# 31  0.011989  75.127658  3.236622  0.939911  83.176269  217.984683      0
# 32 -0.015417  73.272100  2.590375  0.959469  77.192757  166.040006      0
# 33 -0.065250  69.974548  1.335917  1.009986  59.027155  103.471714      0
# 34 -0.108663  67.767584  0.611460  1.049808  60.086751   65.679643      1
# 35  0.033882  75.658096 -0.176698  1.088526  71.831196   82.662910      1
# 36  0.118880  76.934853  0.569190  1.146562  89.500986  121.306552      1
# 37  0.167208  78.012664  1.526350  1.180281  83.992868  152.437875      1
# 38  0.041350  78.786374  2.464593  1.188630  87.280216  146.717786      1
#
# [19 rows x 27 columns]

# %%
df_new_stock = df_new_stock[['volume', 'today', 'previous1', 'previous2', 'previous3', 'previous4', 'previous5',
          'ema50', 'ema21', 'ema14', 'ema5', 'rsi', 'macd', 'obv', 'emv', 'mfi', 'roc', 'atr', 'cmf', 'stoch', 'cci', 'trend']]
df_new_stock
# Out:
#       volume     today  previous1  previous2  previous3  previous4  previous5  \
# 20  0.896113 -0.028011  -0.064038  -0.214389  -0.340944  -0.574470  -0.347615
# 21  1.043712 -0.769338  -0.028011  -0.064038  -0.214389  -0.340944  -0.574470
# 22  0.937985  0.752956  -0.769338  -0.028011  -0.064038  -0.214389  -0.340944
# 23  0.957534  0.579969   0.752956  -0.769338  -0.028011  -0.064038  -0.214389
# 24  0.924709  0.368433   0.579969   0.752956  -0.769338  -0.028011  -0.064038
# 25  0.914830  0.178279   0.368433   0.579969   0.752956  -0.769338  -0.028011
# 26  0.833329  0.239041   0.178279   0.368433   0.579969   0.752956  -0.769338
# 27  1.201855  0.039382   0.239041   0.178279   0.368433   0.579969   0.752956
# 28  1.115363  0.790440   0.039382   0.239041   0.178279   0.368433   0.579969
# 29  1.580469  1.569700   0.790440   0.039382   0.239041   0.178279   0.368433
# 30  1.225941  0.680800   1.569700   0.790440   0.039382   0.239041   0.178279
# 31  1.190345 -0.116049   0.680800   1.569700   0.790440   0.039382   0.239041
# 32  1.036764 -0.388441  -0.116049   0.680800   1.569700   0.790440   0.039382
# 33  1.271597 -1.183883  -0.388441  -0.116049   0.680800   1.569700   0.790440
# 34  1.062242  0.069883  -1.183883  -0.388441  -0.116049   0.680800   1.569700
# 35  1.511513  0.774035   0.069883  -1.183883  -0.388441  -0.116049   0.680800
# 36  1.216711  1.433095   0.774035   0.069883  -1.183883  -0.388441  -0.116049
# 37  1.138291  0.834590   1.433095   0.774035   0.069883  -1.183883  -0.388441
# 38  0.986391  0.532107   0.834590   1.433095   0.774035   0.069883  -1.183883
#
#        ema50     ema21     ema14  ...      macd           obv       emv  \
# 20  0.996134  0.996103  0.996093  ...  0.090517 -8.494694e+04 -0.016232
# 21  0.989103  0.989251  0.989407  ...  0.069902 -4.985003e+06 -0.031951
# 22  0.996735  0.996927  0.997119  ...  0.051474 -6.362485e+05 -0.001250
# 23  1.002385  1.002526  1.002663  ...  0.041131  3.765186e+06  0.079884
# 24  1.005771  1.005806  1.005838  ...  0.040092  7.951890e+06  0.056407
# 25  1.007193  1.007103  1.007017  ...  0.046727  1.202377e+07  0.034416
# 26  1.009142  1.008901  1.008674  ...  0.060232  1.561222e+07  0.018961
# 27  1.009096  1.008713  1.008358  ...  0.077682  2.100699e+07  0.025752
# 28  1.016294  1.015646  1.015051  ...  0.104718  2.613250e+07  0.046815
# 29  1.030791  1.029623  1.028552  ...  0.152514  3.435476e+07  0.137092
# 30  1.036134  1.034377  1.032780  ...  0.217881  4.103579e+07  0.117666
# 31  1.033424  1.031168  1.029147  ...  0.289387  3.429108e+07  0.011989
# 32  1.028174  1.025549  1.023238  ...  0.356470  2.837294e+07 -0.015417
# 33  1.015351  1.012631  1.010295  ...  0.404166  2.069630e+07 -0.065250
# 34  1.015421  1.012575  1.010187  ...  0.437116  2.719006e+07 -0.108663
# 35  1.022366  1.019249  1.016675  ...  0.466272  3.748536e+07  0.033882
# 36  1.035570  1.031922  1.028921  ...  0.505675  4.614871e+07  0.118880
# 37  1.042504  1.038227  1.034718  ...  0.557435  5.448451e+07  0.167208
# 38  1.046219  1.041278  1.037240  ...  0.618978  6.168830e+07  0.041350
#
#           mfi       roc       atr       cmf      stoch         cci  trend
# 20  44.424334 -1.560265  0.834200 -0.137349  35.444452  -60.312614      0
# 21  43.940832 -1.976856  0.845696 -0.147509  14.542379 -117.485860      0
# 22  50.937147 -0.668154  0.854789 -0.109529  34.841994  -77.056360      1
# 23  51.239443  0.249735  0.862848 -0.082901  50.595620    7.833178      1
# 24  50.890086  0.835268  0.857340 -0.059108  60.131143   68.044556      1
# 25  50.230276  1.079766  0.857241 -0.047955  65.085640  101.326029      1
# 26  49.934407  1.349777  0.846847 -0.073763  71.740602  114.408419      1
# 27  50.800286  2.175767  0.844428 -0.098112  72.839617  121.396299      1
# 28  49.243286  2.213781  0.865518 -0.086334  84.144405  154.808103      1
# 29  59.939262  3.219589  0.894838 -0.056902  87.120360  248.476395      1
# 30  68.122889  3.540829  0.917693 -0.045289  85.716030  265.620076      1
# 31  75.127658  3.236622  0.939911 -0.040282  83.176269  217.984683      0
# 32  73.272100  2.590375  0.959469 -0.039201  77.192757  166.040006      0
# 33  69.974548  1.335917  1.009986 -0.091854  59.027155  103.471714      0
# 34  67.767584  0.611460  1.049808 -0.075244  60.086751   65.679643      1
# 35  75.658096 -0.176698  1.088526 -0.035564  71.831196   82.662910      1
# 36  76.934853  0.569190  1.146562  0.008779  89.500986  121.306552      1
# 37  78.012664  1.526350  1.180281  0.033319  83.992868  152.437875      1
# 38  78.786374  2.464593  1.188630  0.027292  87.280216  146.717786      1
#
# [19 rows x 22 columns]

# %% [markdown]
# ## LSTM Model

# %%
X = df_stock.loc[:, df_stock.columns != 'trend']
y = df_stock['trend']
scale = MinMaxScaler(feature_range=(0,1))
X_scaled = scale.fit_transform(X)

timesteps = 15
feature = X_scaled.shape[1]

X_train = []
y_train = []

for i in range(timesteps, len(X_scaled)):
  X_train.append(X_scaled[i-timesteps:i,:])
  y_train.append(y.values[i])


X_train = np.asarray(X_train)
y_train = np.asarray(y_train)

y_train = y_train.reshape(y_train.shape[0], 1)

print("X train dataset shape",X_train.shape)
print("y train dataset shape",y_train.shape)

X_new = df_new_stock.loc[:, df_new_stock.columns != 'trend']
y_new = df_new_stock.loc[:, df_new_stock.columns == 'trend']

X_new_scaled = scale.fit_transform(X_new)

X_test = []
y_test = []

for i in range(timesteps, len(X_new_scaled)):
  X_test.append(X_new_scaled[i-timesteps:i,:])
  y_test.append(y_new.values[i,:])

X_test = np.asarray(X_test)
y_test = np.asarray(y_test)

#y_test = y_test.reshape(y_test.shape[0], 1)

print("X test dataset shape ",X_test.shape)
print("Y test dataset shape ",y_test.shape)
# Out:
# X train dataset shape (1702, 15, 21)
# y train dataset shape (1702, 1)
# X test dataset shape  (4, 15, 21)
# Y test dataset shape  (4, 1)

# %%
lstm_model = Sequential()
lstm_model.add(LSTM(128, return_sequences=True, input_shape=(timesteps, feature)))
lstm_model.add(LSTM(64, return_sequences=False))
lstm_model.add(Dense(1, activation='sigmoid'))
lstm_model.compile(optimizer='adam', loss='mse')

# %%
lstm_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 15, 128)           76800
#
#  lstm_5 (LSTM)               (None, 64)                49408
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 126273 (493.25 KB)
# Trainable params: 126273 (493.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = lstm_model.fit(X_train, y_train, epochs=15, batch_size=8)
# Out:
# Epoch 1/15
# 213/213 [==============================] - 8s 17ms/step - loss: 0.2510
# Epoch 2/15
# 213/213 [==============================] - 6s 26ms/step - loss: 0.2479
# Epoch 3/15
# 213/213 [==============================] - 4s 18ms/step - loss: 0.2468
# Epoch 4/15
# 213/213 [==============================] - 7s 32ms/step - loss: 0.2440
# Epoch 5/15
# 213/213 [==============================] - 8s 36ms/step - loss: 0.2419
# Epoch 6/15
# 213/213 [==============================] - 5s 21ms/step - loss: 0.2301
# Epoch 7/15
# 213/213 [==============================] - 5s 23ms/step - loss: 0.2265
# Epoch 8/15
# 213/213 [==============================] - 4s 18ms/step - loss: 0.2226
# Epoch 9/15
# 213/213 [==============================] - 4s 17ms/step - loss: 0.2206
# Epoch 10/15
# 213/213 [==============================] - 4s 19ms/step - loss: 0.2197
# Epoch 11/15
# 213/213 [==============================] - 5s 22ms/step - loss: 0.2190
# Epoch 12/15
# 213/213 [==============================] - 4s 17ms/step - loss: 0.2176
# Epoch 13/15
# 213/213 [==============================] - 7s 32ms/step - loss: 0.2167
# Epoch 14/15
# 213/213 [==============================] - 8s 39ms/step - loss: 0.2156
# Epoch 15/15
# 213/213 [==============================] - 7s 35ms/step - loss: 0.2160

# %%
y_pred = lstm_model.predict(X_test, batch_size=1)
prediction = (y_pred > 0.5).astype(int)
# Out:
# 4/4 [==============================] - 0s 12ms/step

# %%
accuracy = accuracy_score(prediction, y_test)
classification_rep = classification_report(prediction, y_test)
print("Accuracy: ", accuracy)
print("Classification Report:\n", classification_rep)
# Out:
# Accuracy:  0.75
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.75      1.00      0.86         3
#
#     accuracy                           0.75         4
#    macro avg       0.38      0.50      0.43         4
# weighted avg       0.56      0.75      0.64         4
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## THE END
